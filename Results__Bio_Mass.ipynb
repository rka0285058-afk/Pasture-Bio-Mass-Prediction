# %% [markdown]
# <a href="https://colab.research.google.com/github/rka0285058-afk/Pasture-Bio-Mass-Prediction/blob/main/Results__Bio_Mass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
results_df = pd.DataFrame({
    'image_id': test_df['image_id'],
    'actual_target': test_level_df['target'], # Assuming test_level_df has the actual target values
    'gbr_prediction': y_pred_gbr_test,
    'lgbm_prediction': y_pred_lgbm_test,
    'catboost_prediction': y_pred_catboost_test,
    'xgb_prediction': y_pred_xgb_test,
    'rf_prediction': y_pred_rf_test
})

print("Prediction results for all models against actual targets:")
display(results_df.head())
# Out:
# Prediction results for all models against actual targets:
#        image_id  actual_target  gbr_prediction  lgbm_prediction  \
# 0  ID1001187975             15        8.872174          3.06241
# 1  ID1001187975             10        8.872174          3.06241
# 2  ID1001187975             35        8.872174          3.06241
# 3  ID1001187975             30        8.872174          3.06241
# 4  ID1001187975             10        8.872174          3.06241
#
#    catboost_prediction  xgb_prediction  rf_prediction
# 0             7.239955       -0.417073         2.4309
# 1             7.239955       -0.417073         2.4309
# 2             7.239955       -0.417073         2.4309
# 3             7.239955       -0.417073         2.4309
# 4             7.239955       -0.417073         2.4309
